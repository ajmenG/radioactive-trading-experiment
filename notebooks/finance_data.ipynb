# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
df = pd.read_csv("../data/data.csv")

# %%
pd.DataFrame(df)
# Out:
#         z    n     name levelEnergy(MeV) spinAndParity decayMode  \
# 0       0    1  Neutron                0          1/2+        B-
# 1       1    2       3H                0          1/2+        B-
# 2       1    3       4H                0            2-         N
# 3       1    4       5H                0        (1/2+)        2N
# 4       1    6       7H                0          1/2+        2N
# ...   ...  ...      ...              ...           ...       ...
# 6338  116  177    293Lv                0           NaN         A
# 6339  117  176    293Ts                0           NaN         A
# 6340  117  177    294Ts                0           NaN         A
# 6341  118  176    294Og                0            0+         A
# 6342  118  176    294Og                0            0+        SF
#
#       branchingRatio  branchingRatioUncertainty  massExcess(keV)  \
# 0              100.0                        NaN           8070.0
# ...
